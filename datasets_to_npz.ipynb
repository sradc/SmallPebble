# %%
import numpy as np
from smallpebble.datasets import load_data

X_train, y_train, X_test, y_test = load_data('mnist')
np.savez_compressed(
    'smallpebble_mnist.npz', 
    X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test
)
X_train, y_train, X_test, y_test = load_data('cifar')
np.savez_compressed(
    'smallpebble_cifar.npz', 
    X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test
)
# Out:
# Processing MNIST...
# Processing CIFAR...
